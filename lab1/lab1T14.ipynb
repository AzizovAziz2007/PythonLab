# %%
def non_empty(func):
    def wrapper():
        original_result = func()

        cleaned_result = [x for x in original_result if x != '' and x is not None]
        
        return cleaned_result
    return wrapper

@non_empty
def get_pages():
    return ['chapter1', '', 'contents', None, 'line1']

print(get_pages())
# Out:
# ['chapter1', 'contents', 'line1']
