# %%
password = input("Введите пароль: ")

has_digit = any(char.isdigit() for char in password)

has_upper = any(char.isupper() for char in password)

if has_digit and has_upper and len(password) >= 8:
    print("Ваш пароль надёжный!")
else:
    print("Пароль должен содержать хотя бы одну заглавную букву, одну цифру и не быть короче 8 символов!")
# Out:
# Введите пароль:  passWord1234
# Ваш пароль надёжный!
